# %%
import pandas as pd

from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('/Users/hankiho/Desktop/Data/Kaggle/StudentsPerformance.csv')

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
for i in df.columns:
    print(i + " : " + str(len(df[i].value_counts())))
# Out:
# gender : 2
# race/ethnicity : 5
# parental level of education : 6
# lunch : 2
# test preparation course : 2
# math score : 81
# reading score : 72
# writing score : 77

# %%
df['average score'] = (df['math score'] + df['reading score'] + df['writing score']) / 3

# %%
sns.pairplot(data = df, hue = 'gender')
# Out:
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print ('상관계수:', df['math score'].corr(df['writing score']))
print ('------------')
slope, intercept, rvalue, pvalue, stderr = stats.linregress(df['math score'], df['writing score'])
def predict(x):
    return (x * slope + intercept)
print (predict(6))
# Out:
# 상관계수: 0.8026420459498078
# ------------
# 19.72042309856622

# %%
sns.jointplot(data = df, x = 'math score', y = 'reading score')
# Out:
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.scatterplot(data = df, x = 'writing score', y = 'reading score')

# %%
sns.regplot(data = df, x = 'writing score', y = 'reading score')

# %%
sns.lineplot(data = df, x = 'math score', y = 'reading score', hue = 'gender')

# %%
sns.stripplot(data = df, x = 'test preparation course', y = 'average score')

# %%
sns.countplot(data = df, x = 'lunch', hue = 'gender')

# %%
sns.barplot(data = df, x = 'race/ethnicity', y = 'average score')

# %%
sns.violinplot(data = df, x = 'race/ethnicity', y = 'average score')

# %%
sns.pointplot(data = df, x = 'race/ethnicity', y = 'average score')

# %%
plt.figure(figsize = (20,10))
sns.boxenplot(data = df, x = 'parental level of education', y = 'average score')

# %%
sns.distplot(df['average score'], bins = 20)

# %%
sns.catplot(data = df, x = 'lunch', y = 'average score', hue = 'gender', kind = 'boxen')
